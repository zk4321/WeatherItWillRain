# %% [markdown]
# 1. Import libraries

# %%
# For data 
import pandas as pd
import numpy as np

# For plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Plot grid on a white background
sns.set_style("whitegrid")

# %% [markdown]
# 2. Import data

# %%
# set working directory/file path
df_file_path = "/Users/rebeccab/1-erdos/group_project/weatherAUS.csv"

# read in the data and store in a dataframe
df = pd.read_csv(df_file_path)

# %%
# drop NA rows
df = df.dropna(axis = 0)

# %%
# designate features (potential explanatory variables) and the target (response variable)
X = df.drop(['RainTomorrow'], axis=1)
y = df['RainTomorrow']

# %%
# histograms
fig, axes = plt.subplots(3,6, figsize=(30,10))

plt.subplot(3,6,1)
plt.hist(X.MinTemp[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.MinTemp[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "MinTemp")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,2)
plt.hist(X.MaxTemp[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.MaxTemp[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "MaxTemp")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,3)
plt.hist(X.Rainfall[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.Rainfall[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "Rainfall")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,4)
plt.hist(X.Evaporation[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.Evaporation[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "Evaporation")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,5)
plt.hist(X.Sunshine[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.Sunshine[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "Sunshine")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,6)
plt.hist(X.WindGustSpeed[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.WindGustSpeed[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "WindGustSpeed")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,7)
plt.hist(X.WindSpeed9am[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.WindSpeed9am[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "WindSpeed9am")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,8)
plt.hist(X.WindSpeed3pm[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.WindSpeed3pm[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "WindSpeed3pm")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,9)
plt.hist(X.Humidity9am[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.Humidity9am[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "Humidity9am")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,10)
plt.hist(X.Humidity3pm[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.Humidity3pm[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "Humidity3pm")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,11)
plt.hist(X.Pressure9am[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.Pressure9am[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "Pressure9am")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,12)
plt.hist(X.Pressure3pm[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.Pressure3pm[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "Pressure3pm")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,13)
plt.hist(X.Cloud9am[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.Cloud9am[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "Cloud9am")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,14)
plt.hist(X.Cloud3pm[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.Cloud3pm[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "Cloud3pm")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,15)
plt.hist(X.Temp9am[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.Temp9am[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "Temp9am")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,16)
plt.hist(X.Temp3pm[y == "Yes"], color = "red", alpha = .5)
plt.hist(X.Temp3pm[y == "No"], color = "blue", alpha = .3)
plt.gca().set(title = "Temp3pm")
plt.legend(['RainTomorrow = Yes', 'RainTomorrow = No'], loc = 'best')

plt.subplot(3,6,17).set_visible(False)

plt.subplot(3,6,18).set_visible(False)

plt.savefig("feature_histograms_alldata.png", dpi=500)
